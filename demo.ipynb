# %% [markdown]
# # Personal Budget Assistant – Demo Notebook
#
# This notebook demonstrates the CSE476 CA1 T1 Personal Budget Assistant.
#
# **Features:** Plan–Act Loop, Tool Calling, Memory, Multi-step Trace.

# %% [markdown]
# ## Step 1: Import the Agent
# Keep this notebook in the same folder as `app.py`, `tools.py`, `schemas.py`, `registry.py`, `memory.py`, and `config.py`.

# %%
from app import run_agent

print("Agent imported successfully!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from app import run_agent
#       2
#       3 print("Agent imported successfully!")
#
# File c:\Users\vikas\Downloads\Personal-Budget-Assistant--main\Personal-Budget-Assistant--main\app.py:5
#       1 # app.py
#       3 import json
# ----> 5 from config import client, MODEL
#       6 from schemas import TOOLS
#       7 from registry import REGISTRY
#
# File c:\Users\vikas\Downloads\Personal-Budget-Assistant--main\Personal-Budget-Assistant--main\config.py:5
#       3 import os
#       4 from dotenv import load_dotenv
# ----> 5 from openai import OpenAI
#       7 load_dotenv()
#       9 MODEL = "openai/gpt-oss-20b"
#
# ModuleNotFoundError: No module named 'openai'

# %% [markdown]
# ## Demo 1 – Add First Expense

# %%
run_agent("Add ₹250 for pizza.")

# %% [markdown]
# ## Demo 2 – Add Another Expense

# %%
run_agent("Add ₹120 for metro.")

# %% [markdown]
# ## Demo 3 – Get Spending Summary

# %%
run_agent("How much have I spent so far?")

# %% [markdown]
# ## Demo 4 – Agentic Decision Making

# %%
run_agent("Can I afford a ₹2000 trip?")

# %% [markdown]
# ## Demo 5 – Memory Test

# %%
run_agent("Which category have I spent money on?")

# %% [markdown]
# ## Viva Explanation
#
# - **Tool 1:** `add_expense(item, amount)`
# - **Tool 2:** `get_summary(category)`
# - **Memory:** Uses `BudgetMemory.messages`.
# - **Plan–Act Loop:** Model chooses a tool → Registry executes it → Tool result returns to the model → Final answer.
